# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahra-Bakhtiari/Graph_Neural_Network_for_biological_predictions/blob/master/BioKnowledgeGraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
! mkdir -p /root/.ssh
with open("/root/.ssh/id_rsa", mode="w") as fp:
    fp.write("""
-----BEGIN RSA PRIVATE KEY-----

-----END RSA PRIVATE KEY-----
""")
! ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
! chmod go-rwx /root/.ssh/id_rsa
! git clone git@github.com:Zahra-Bakhtiari/Graph_Neural_Network_for_biological_predictions.git
# %cd /content/Graph_Neural_Network_for_biological_predictions
# Out:
# # github.com:22 SSH-2.0-babeld-8eb00d7e
# Cloning into 'Graph_Neural_Network_for_biological_predictions'...
# ...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 5 (delta 0), pack-reused 0
# Receiving objects: 100% (5/5), 7.62 KiB | 7.62 MiB/s, done.
# /content/Graph_Neural_Network_for_biological_predictions

# %%
import torch
import os
# Install torch geometric
if 'IS_GRADESCOPE_ENV' not in os.environ:
  # !pip install ogb
  # !pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 78 kB 3.2 MB/s
# ...
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7048 sha256=916ea86cf7dd44493fcf965ac2648a6fac0f3943afc383a1fabe5eed29decf8d
#   Stored in directory: /root/.cache/pip/wheels/d6/64/cd/32819b511a488e4993f2fab909a95330289c3f4e0f6ef4676d
# Successfully built littleutils
# ...
#      |████████████████████████████████| 124 kB 4.3 MB/s
# ...

# %%
# %cd /content/gdrive/MyDrive/ColabScripts/Graph_Neural_Network_for_biological_predictions/


! CUDA_VISIBLE_DEVICES=0 python3 run.py --do_train --cuda --do_valid --do_test \
  --model RotatE -n 128 -b 512 -d 1000 -g 20 -a 1.0 -adv \
  -lr 0.0001 --max_steps 300000 --cpu_num 2 --test_batch_size 32 -de
# Out:
# /content/gdrive/MyDrive/ColabScripts/Graph_Neural_Network_for_biological_predictions
# 2021-12-06 23:37:06,260 INFO     Model: RotatE
# 2021-12-06 23:37:06,261 INFO     Dataset: ogbl-biokg
# 2021-12-06 23:37:06,262 INFO     #entity: 93773
# 2021-12-06 23:37:06,262 INFO     #relation: 51
# 2021-12-06 23:37:06,262 INFO     #train: 4762678
# 2021-12-06 23:37:06,262 INFO     #valid: 162886
# 2021-12-06 23:37:06,262 INFO     #test: 162870
# 100% 4762678/4762678 [00:16<00:00, 280995.96it/s]
# 2021-12-06 23:37:24,631 INFO     Model Parameter Configuration:
# 2021-12-06 23:37:24,632 INFO     Parameter gamma: torch.Size([1]), require_grad = False
# 2021-12-06 23:37:24,632 INFO     Parameter embedding_range: torch.Size([1]), require_grad = False
# 2021-12-06 23:37:24,632 INFO     Parameter entity_embedding: torch.Size([93773, 2000]), require_grad = True
# 2021-12-06 23:37:24,632 INFO     Parameter relation_embedding: torch.Size([51, 1000]), require_grad = True
# ...

# %%
# %cd /content/gdrive/MyDrive/ColabScripts/Graph_Neural_Network_for_biological_predictions/


! CUDA_VISIBLE_DEVICES=0 python3 run.py --do_train --cuda --do_valid --do_test \
  --model pRotatE -n 128 -b 512 -d 1000 -g 20 -a 1.0 -adv \
  -lr 0.0001 --max_steps 300000 --cpu_num 2 --test_batch_size 32
# Out:
# /content/gdrive/MyDrive/ColabScripts/Graph_Neural_Network_for_biological_predictions
# 2021-12-07 00:10:35,052 INFO     Model: pRotatE
# 2021-12-07 00:10:35,053 INFO     Dataset: ogbl-biokg
# 2021-12-07 00:10:35,053 INFO     #entity: 93773
# 2021-12-07 00:10:35,053 INFO     #relation: 51
# 2021-12-07 00:10:35,054 INFO     #train: 4762678
# 2021-12-07 00:10:35,054 INFO     #valid: 162886
# 2021-12-07 00:10:35,054 INFO     #test: 162870
# 100% 4762678/4762678 [00:17<00:00, 278477.37it/s]
# 2021-12-07 00:10:52,871 INFO     Model Parameter Configuration:
# 2021-12-07 00:10:52,871 INFO     Parameter gamma: torch.Size([1]), require_grad = False
# 2021-12-07 00:10:52,871 INFO     Parameter embedding_range: torch.Size([1]), require_grad = False
# 2021-12-07 00:10:52,872 INFO     Parameter entity_embedding: torch.Size([93773, 1000]), require_grad = True
# 2021-12-07 00:10:52,872 INFO     Parameter relation_embedding: torch.Size([51, 1000]), require_grad = True
# ...

# %%
# %cd /content/gdrive/MyDrive/ColabScripts/Graph_Neural_Network_for_biological_predictions/


! CUDA_VISIBLE_DEVICES=0 python3 run.py --do_train --cuda --do_valid --do_test \
  --model TransE -n 128 -b 512 -d 2000 -g 20 -a 1.0 -adv \
  -lr 0.0001 --max_steps 300000 --cpu_num 2 --test_batch_size 32
